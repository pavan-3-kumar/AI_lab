# %%
def bfs(a):
    ans=[]
    k = 1
    p=0
    end=4
    vis=[0]*14
    ans.append(0)
    while(k<=13):
        print(ans[p],end=" ")
        if(ans[p]==destination):
            break
        k+=1
        vis[ans[p]]=1
        if(len(a[ans[p]])==0):
            p+=1
            continue
        for j in a[ans[p]]:
            if(vis[j]==0):
                ans.append(j)
                vis[j]=1
        p+=1

# %%
a=[[5,1,2,11],[0,7,3],[0,10,12],[1,9,4],[3],[0,6,7],[5],[1,5,8],[7],[3],[2],[0],[2]]
destination = 4

# %%
bfs(a)
# Out:
# 0 5 1 2 11 6 7 3 10 12 8 9 4

# %%
 def dfs(a,source):
    ans=[source]
    vis=[0]*13
    vis[0]=1
    while(len(ans)):
        print(ans[-1],end=" ")
        t= ans[-1]
        ans.pop()
        for i in a[t]:
            if(vis[i]==0):
                ans.append(i)
                vis[i]=1

# %%
dfs(a,0)
# Out:
# 0 11 2 12 10 1 3 4 9 7 8 5 6

# %%
# BFS

# %%
def bfs(adj, start , vis , goal):
    p=[start]
    openlist=[start]
    print("openlist   --  closelist")
    while len(p) > 0: 
        node = p[0]
        vis[ord(node)-96]=1
        print(openlist,end="  ")
        print(closelist[::-1])
        if(node == goal):
            print("goal reached")
            return 
        closelist.append(node)
        openlist=openlist[1:]
#         print(node)
        p=p[1:]
        for i in adj[node]:
            if vis[ord(i)-96]==0:
                p.append(i)
                vis[ord(i)-96]=1
                openlist.append(i)

# %%
adj={'a':['b','c','d'],'b':['e','f'] , 'c':['f','g'],'d':[],'e':['h','i'],'f':['j'],'g':[],'h':[],'i':[],'j':[]}
start='a'
goal ='g'
vis=[0]*(len(adj)+1)
closelist=[]
openlist=[]
bfs(adj, start , vis , goal )
# Out:
# openlist   --  closelist
# ['a']  []
# ['b', 'c', 'd']  ['a']
# ['c', 'd', 'e', 'f']  ['b', 'a']
# ['d', 'e', 'f', 'g']  ['c', 'b', 'a']
# ['e', 'f', 'g']  ['d', 'c', 'b', 'a']
# ['f', 'g', 'h', 'i']  ['e', 'd', 'c', 'b', 'a']
# ['g', 'h', 'i', 'j']  ['f', 'e', 'd', 'c', 'b', 'a']
# goal reached

# %%
#dfs

# %%
def dfs(adj , vis ,goal , openlist , closelist):
    while openlist != []:
        print(openlist, closelist)
        node = openlist.pop(0)
        if node == goal:
            print("goal is found")
            return 
        closelist.append(node)
        for i in adj[node]:
            if vis[ord(i)-96]==0 :
                vis[ord(i)-96]=1
                openlist.insert(0,i)

# %%
adj={'a':['b','c','d'],'b':['e','f'] , 'c':['f','g'],'d':[],'e':['h','i'],'f':['j'],'g':[],'h':[],'i':[],'j':[]}
# start='a'
goal ='g'
vis=[0]*(len(adj)+1)
vis[ord('a')-96]=1
openlist=['a']
closelist=[]
dfs(adj , vis , goal , openlist , closelist)

# %% [markdown]
# #uniform cost search

# %%
def uniform(adj , vis , goal , start ):
    queue = []
    ans = 10**8
    closed=[]
    queue.append([0 , start])
    while queue != []:
        queue=sorted(queue,reverse=True)
        print(queue,end="    ")
        print(closed)
        pa = queue[-1]
        queue.pop()
        closed.append([pa[1],pa[0]])
#         pa[0]*=-1
        if pa[1]== goal:
            if ans > abs(pa[0]):
                ans = abs(pa[0])
            print("goal is reached")
            return ans 
        if vis[ord(pa[1])-96] == 0 :
            for i in adj[pa[1]]:
                queue.append([(abs(pa[0]) + i[1])  , i[0]])
        vis[ord(pa[1])-96] = 1

# %%
adj={'a':[('b',6),('c',4)],'b':[('d',4)],'c':[('f',8)],'d':[('g',2)],'g':[('h',3),('e',9)],'f':[('h',7),('e',9)],
     'h':[('e',4)],'e':[]}
# graph in pdf 
vis=[0]*9
vis[0]=1
print("open    closed")
print(uniform(adj , vis , 'e' , 'a'))
# Out:
# open    closed
# [[0, 'a']]    []
# [[6, 'b'], [4, 'c']]    [['a', 0]]
# [[12, 'f'], [6, 'b']]    [['a', 0], ['c', 4]]
# [[12, 'f'], [10, 'd']]    [['a', 0], ['c', 4], ['b', 6]]
# [[12, 'g'], [12, 'f']]    [['a', 0], ['c', 4], ['b', 6], ['d', 10]]
# [[21, 'e'], [19, 'h'], [12, 'g']]    [['a', 0], ['c', 4], ['b', 6], ['d', 10], ['f', 12]]
# [[21, 'e'], [21, 'e'], [19, 'h'], [15, 'h']]    [['a', 0], ['c', 4], ['b', 6], ['d', 10], ['f', 12], ['g', 12]]
# [[21, 'e'], [21, 'e'], [19, 'h'], [19, 'e']]    [['a', 0], ['c', 4], ['b', 6], ['d', 10], ['f', 12], ['g', 12], ['h', 15]]
# goal is reached
# 19

# %% [markdown]
# # iterative deepening depth first search

# %%
def dedfs(de , adj , target):
    vis = [1]
    check =[0]
    s=[1]
    while s != []:
        pa = s.pop()
        print(pa ,end=" ")
        p= check.pop()
        if pa == target :
            print("goal is reached within in level")
            return 1
        if p+1 > de:
            continue 
        for i in adj[pa]:
            if i in vis :
                continue
            vis.append(i)
            check.append(p+1)
            s.append(i)
    return 0                
        



def solve(depth, adj , target):
    for i in range(depth+1):
        print('depth-',i,":",end=" ")
        if(dedfs(i, adj , target)):
            break
        print()

# %%
adj={1:[2,5],2:[3,4],3:[8,9],5:[6,7],7:[10,11]}
source = 1
depth = 2
target = 6
solve(depth, adj , target)
# Out:
# depth- 0 : 1
# depth- 1 : 1 5 2
# depth- 2 : 1 5 7 6 goal is reached within in level

# %%
# another solution 

d=2
s=1
target=6
adj={1:[2,5],2:[3,4],3:[8,9],5:[6,7],7:[10,11]}

f=0
for k in range(3):
    open=[(s,0)]
    closed=[]
    if f==1:
        break
    vi=[0 for l in range(100)]
    vi[s]=1
    while len(open)>0:
        a=open[0]
        open=open[1:]
        if a[1]>k:
            continue
        closed.insert(0,a[0])
        if a[0]==target:
            print(open,closed,'target found at depth ',k)
            f=1
            break
        u=[]
        for i in adj[a[0]]:
            if vi[i]==0:
                vi[i]=1
                u.append(i)
        u=u[::-1]
        for i in u:
            open.insert(0,(i,a[1]+1))
        print('open list :',open,' closed list : ',closed)
    print()
# Out:
# open list : [(2, 1), (5, 1)]  closed list :  [1]
#
# open list : [(2, 1), (5, 1)]  closed list :  [1]
# open list : [(3, 2), (4, 2), (5, 1)]  closed list :  [2, 1]
# open list : [(6, 2), (7, 2)]  closed list :  [5, 2, 1]
#
# open list : [(2, 1), (5, 1)]  closed list :  [1]
# open list : [(3, 2), (4, 2), (5, 1)]  closed list :  [2, 1]
# open list : [(8, 3), (9, 3), (4, 2), (5, 1)]  closed list :  [3, 2, 1]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4976\2864374312.py in <module>
#      25             break
#      26         u=[]
# ---> 27         for i in adj[a[0]]:
#      28             if vi[i]==0:
#      29                 vi[i]=1
#
# KeyError: 4

# %%
# bidirectional

# %%
from collections import defaultdict
graph=defaultdict(list)

edges=eval(input('Enter edges: '))
for i in edges:
  graph[i[0]].append(i[1])
  graph[i[1]].append(i[0])

src=int(input('Enter initial state: '))
dest=int(input('Enter goal state: '))
visit_f=[src]
visit_b=[dest]
front_f,top_f,front_b,top_b=0,0,0,0

def bfs_f():
  if src==dest:
    return src
  global front_f,top_f

  while front_f<=top_f:
    s=visit_f[front_f]
    for i in graph[s]:
      if i not in visit_f:
        visit_f.append(i)tgit
        top_f=top_f+1
        if i in visit_b:
          return i
        else:
          k=bfs_b()
          if k!=-1: return k

    front_f=front_f+1
  return -1

def bfs_b():
  global front_b,top_b

  while front_b<=top_b:
    s=visit_b[front_b]
    for i in graph[s]:
      if i not in visit_b:
        visit_b.append(i)
        top_b=top_b+1
        if i in visit_f:
          return i
        else:
          k=bfs_f()
          if k!=-1: return k

    front_b=front_b+1
  return -1

def remove(l,g):
  a=l.index(g)
  for i in range(a,0,-1):
    if [l[i],l[i-1]] not in edges and [l[i-1],l[i]] not in edges:
      l.remove(l[i-1])
  a=l.index(g)
  return a

g=bfs_f()
if g==-1:
  print('No intersection')
else:
  print('\nIntersection Node:',g)
  a=remove(visit_f,g)
  b=remove(visit_b,g)
  k=visit_f[:a]+visit_b[b::-1]
  print('Path :',k)

#[[1,2],[1,5],[2,3],[2,4],[3,8],[3,9],[5,6],[5,7],[7,10],[7,11]]
# Out:
# Enter edges: [[1,2],[1,5],[2,3],[2,4],[3,8],[3,9],[5,6],[5,7],[7,10],[7,11]]
# 1
# 2
# 5
# 3
# 4
# 8
# 9
# 6
# 7
# 10
# 11
# Enter initial state: 1
# Enter goal state: 9
#
# Intersection Node: 2
# Path : [1, 2, 3, 9]

# %% [markdown]
# # waterjug_bfs

# %%
def water(m , n , goal, closelist):
    a,b=0,0
    ans=[(0,0)]
    d={}
    for i in range(m+1):
        for j in range(n+1):
            d[(i,j)]=0
    for i in range(n+1):
        for j in range(m+1):
            d[(i,j)]=0
   
    while(len(ans)>0):
#         for i in ans:
#             print(i," ")
#         print()
        print(ans,end="  ")
        print(closelist)
        a,b=ans[0]
#         print(ans[0])
        ans=ans[1:]
        closelist.append((a,b))
        d[(a,b)]=1
#         print(a," - ",b)
        
        if((a==goal and b==0) or (a==0 and b==goal)):
            print("goal received")
            break        
        if(d[(m,b)]==0):
            ans.append((m,b))
            d[(m,b)]=1
        if(d[(a,n)]==0):
            ans.append((a,n))
            d[(a,n)]=1
        if(not(b-m+a <0)):
            if(d[(m,b-m+a)]==0):
                ans.append((m,b-m+a))
                d[m,b-m+a]=1
        if(not(a-n+b < 0)):
            if(d[(a-n+b , n)]==0):
                ans.append((a-n+b , n))
                d[(a-n+b , n)]=1
        if(not(a+b>m)):
            if(d[(a+b,0)]==0):
                ans.append((a+b,0))
                d[(a+b,0)]=1
        if(not(a+b>n)):
            if(d[(0,a+b)]==0):
                ans.append((0,a+b))
                d[(0,a+b)]=1
        if(d[(0,b)]==0):
            ans.append((0,b))
        if(d[(a,0)]==0):
            ans.append((a,0))

# %%
closelist = []
print("open      closelist")
water(5,2,4 , closelist)
# Out:
# open      closelist
# [(0, 0)]  []
# 0  -  0
# [(5, 0), (0, 2)]  [(0, 0)]
# 5  -  0
# [(0, 2), (5, 2), (3, 2)]  [(0, 0), (5, 0)]
# 0  -  2
# [(5, 2), (3, 2), (2, 0)]  [(0, 0), (5, 0), (0, 2)]
# 5  -  2
# [(3, 2), (2, 0)]  [(0, 0), (5, 0), (0, 2), (5, 2)]
# 3  -  2
# [(2, 0), (3, 0)]  [(0, 0), (5, 0), (0, 2), (5, 2), (3, 2)]
# 2  -  0
# [(3, 0), (2, 2)]  [(0, 0), (5, 0), (0, 2), (5, 2), (3, 2), (2, 0)]
# 3  -  0
# [(2, 2), (1, 2)]  [(0, 0), (5, 0), (0, 2), (5, 2), (3, 2), (2, 0), (3, 0)]
# 2  -  2
# [(1, 2), (4, 0)]  [(0, 0), (5, 0), (0, 2), (5, 2), (3, 2), (2, 0), (3, 0), (2, 2)]
# 1  -  2
# [(4, 0), (1, 0)]  [(0, 0), (5, 0), (0, 2), (5, 2), (3, 2), (2, 0), (3, 0), (2, 2), (1, 2)]
# 4  -  0
# goal received

# %% [markdown]
# # waterjug_dfs

# %%
def waterjug_dfs(m , n , goal):
    ans=[(0,0)]
    d={}
    for i in range(m+1):
        for j in range(n+1):
            d[(i,j)]=0
    for i in range(n+1):
        for j in range(m+1):
            d[(i,j)]=0
    closelist=[]
    d[(0,0)]=1
    while ans:
        print(ans,end="   ")
        print(closelist)
        pa = ans.pop()
        closelist.append(pa)
        a,b=pa[0],pa[1]
        if (a==goal and b==0) or (a==0 and b==goal):
            print("goal is reached")
            return 
        if(d[(m,b)]==0):
            ans.append((m,b))
            d[(m,b)]=1
        if(d[(a,n)]==0):
            ans.append((a,n))
            d[(a,n)]=1
        if(not(b-m+a <0)):
            if(d[(m,b-m+a)]==0):
                ans.append((m,b-m+a))
                d[m,b-m+a]=1
        if(not(a-n+b < 0)):
            if(d[(a-n+b , n)]==0):
                ans.append((a-n+b , n))
                d[(a-n+b , n)]=1
        if(not(a+b>m)):
            if(d[(a+b,0)]==0):
                ans.append((a+b,0))
                d[(a+b,0)]=1
        if(not(a+b>n)):
            if(d[(0,a+b)]==0):
                ans.append((0,a+b))
                d[(0,a+b)]=1
        if(d[(0,b)]==0):
            ans.append((0,b))
        if(d[(a,0)]==0):
            ans.append((a,0))

# %%
print("open           closedlist")
waterjug_dfs(5,2,4)
# Out:
# open           closedlist
# [(0, 0)]   []
# [(5, 0), (0, 2)]   [(0, 0)]
# [(5, 0), (5, 2), (2, 0)]   [(0, 0), (0, 2)]
# [(5, 0), (5, 2), (2, 2)]   [(0, 0), (0, 2), (2, 0)]
# [(5, 0), (5, 2), (4, 0)]   [(0, 0), (0, 2), (2, 0), (2, 2)]
# goal is reached

# %% [markdown]
# # missiombnaries and cannibals

# %%
#BFS

visited=[[(3,3),(0,0),'left']]
front,top=0,0
f=0
closelist=[]
def check(a,b,c,d):
  if (a==0 or a>=b) and (c==0 or c>=d):
    return 1
  return 0

def add(p,q,r):
  global top
  visited.append([p,q,r])
  top+=1

while front<=top:
    print(visited[front:],end="      ")
    print(closelist)
    (l_m,l_c),(r_m,r_c),boat_side=visited[front]
    closelist.append(visited[front])

    if r_m==3 and r_c==3:
        f=1
        break

    if boat_side=='left':
        if l_m>=1:
            a,b,c,d=l_m-1,l_c,r_m+1,r_c
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
        if l_c>=1:
            a,b,c,d=l_m,l_c-1,r_m,r_c+1
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                 add((a,b),(c,d),'right')
        if l_m>=1 and l_c>=1:
            a,b,c,d=l_m-1,l_c-1,r_m+1,r_c+1
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
        if l_m>=2:
            a,b,c,d=l_m-2,l_c,r_m+2,r_c
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
        if l_c>=2:
            a,b,c,d=l_m,l_c-2,r_m,r_c+2
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')

    else:
        if r_m>=1:
            a,b,c,d=l_m+1,l_c,r_m-1,r_c
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
        if r_c>=1:
            a,b,c,d=l_m,l_c+1,r_m,r_c-1
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
        if r_m>=1 and r_c>=1:
            a,b,c,d=l_m+1,l_c+1,r_m-1,r_c-1
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
        if r_m>=2:
            a,b,c,d=l_m+2,l_c,r_m-2,r_c
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
        if r_c>=2:
            a,b,c,d=l_m,l_c+2,r_m,r_c-2
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')

    front+=1

if f==1:
    visited=visited[:front+1]
    print('States traversed:')
#     print(visited)
else:
    print('No solution')
# Out:
# [[(3, 3), (0, 0), 'left']]      []
# [[(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right']]      [[(3, 3), (0, 0), 'left']]
# [[(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right']]
# [[(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right']]
# [[(3, 2), (0, 1), 'left']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right']]
# [[(3, 0), (0, 3), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left']]
# [[(3, 1), (0, 2), 'left']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right']]
# [[(1, 1), (2, 2), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left']]
# [[(2, 2), (1, 1), 'left']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right']]
# [[(0, 2), (3, 1), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left']]
# [[(0, 3), (3, 0), 'left']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right']]
# [[(0, 1), (3, 2), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left']]
# [[(1, 1), (2, 2), 'left'], [(0, 2), (3, 1), 'left']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left'], [(0, 1), (3, 2), 'right']]
# [[(0, 2), (3, 1), 'left'], [(0, 0), (3, 3), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left'], [(0, 1), (3, 2), 'right'], [(1, 1), (2, 2), 'left']]
# [[(0, 0), (3, 3), 'right']]      [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left'], [(0, 1), (3, 2), 'right'], [(1, 1), (2, 2), 'left'], [(0, 2), (3, 1), 'left']]
# States traversed:

# %%
#3.	Implement Missionaries and Cannibals problem with Search tree generation using
#a.DFS
f =0 
top =0 
def check(a,b,c,d):
    if (a==0 or a>=b) and (c==0 or c>=d):
        return 1
    return 0
def add(p,q,r):
    global visited , top
    visited.append([p,q,r])
    top+=1
closelist=[]

while top >= 0:
    print(visited[:top+1],end="  ")
    print(closelist)
    (l_m,l_c),(r_m,r_c),boat_side=visited[top]
#     visited.pop()
    if r_m==3 and r_c==3:
        f=1
        break
        closelist.append(visited[top])


    che = 0 
    if boat_side=='left':
        if l_m>=1:
            a,b,c,d=l_m-1,l_c,r_m+1,r_c
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
                che = 1
        if l_c>=1:
            a,b,c,d=l_m,l_c-1,r_m,r_c+1
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
                che = 1
        if l_m>=1 and l_c>=1:
            a,b,c,d=l_m-1,l_c-1,r_m+1,r_c+1
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
                che = 1
        if l_m>=2:
            a,b,c,d=l_m-2,l_c,r_m+2,r_c
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
                che = 1
        if l_c>=2:
            a,b,c,d=l_m,l_c-2,r_m,r_c+2
            if [(a,b),(c,d),'right'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'right')
                che = 1

    else:
        if r_m>=1:
            a,b,c,d=l_m+1,l_c,r_m-1,r_c
            if [(a,b),(c,d),'left']not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
                che = 1
        if r_c>=1:
            a,b,c,d=l_m,l_c+1,r_m,r_c-1
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
                che = 1
        if r_m>=1 and r_c>=1:
            a,b,c,d=l_m+1,l_c+1,r_m-1,r_c-1
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
                che = 1
        if r_m>=2:
            a,b,c,d=l_m+2,l_c,r_m-2,r_c
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
                che = 1
        if r_c>=2:
            a,b,c,d=l_m,l_c+2,r_m,r_c-2
            if [(a,b),(c,d),'left'] not in visited and check(a,b,c,d):
                add((a,b),(c,d),'left')
                che = 1
    if(che == 0 ):
        top-=1


l_m,l_c,r_m,r_c=3,3,0,0
visited=[[(l_m,l_c),(r_m,r_c),'left']]

if f==1:
    print('States traversed:')
#     print(visited)
else:
    print('No solution')
# Out:
# [[(3, 3), (0, 0), 'left']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left'], [(0, 1), (3, 2), 'right']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left'], [(0, 1), (3, 2), 'right'], [(1, 1), (2, 2), 'left'], [(0, 2), (3, 1), 'left']]  []
# [[(3, 3), (0, 0), 'left'], [(3, 2), (0, 1), 'right'], [(2, 2), (1, 1), 'right'], [(3, 1), (0, 2), 'right'], [(3, 2), (0, 1), 'left'], [(3, 0), (0, 3), 'right'], [(3, 1), (0, 2), 'left'], [(1, 1), (2, 2), 'right'], [(2, 2), (1, 1), 'left'], [(0, 2), (3, 1), 'right'], [(0, 3), (3, 0), 'left'], [(0, 1), (3, 2), 'right'], [(1, 1), (2, 2), 'left'], [(0, 2), (3, 1), 'left'], [(0, 0), (3, 3), 'right']]  []
# States traversed:

# %% [markdown]
# # best first search

# %%
#14/06/2023, 21/06/2023
#Greedy Best First Search
from collections import defaultdict

nodes=eval(input('Enter nodes with coordinates: '))
edges=eval(input('Enter edges: '))
graph=defaultdict(list)
for i in edges:
  graph[i[0]].append(i[1])
  graph[i[1]].append(i[0])


src=input('Enter source: ')
dest=input('Enter destination: ')

hc={} #heuristic
for i in nodes.keys():
  hc[i]=abs(nodes[i][0]-nodes[dest][0])+abs(nodes[i][1]-nodes[dest][1])  #Manhattan

l=[]
s=[]
k=src
f=0

while 1:
  s.append(k)
  if k==dest:
    f=1
    break
  for i in graph[k]:
    if i not in s:
      l.append([hc[i],k,i])
  if len(l)==0:
    break
  m=min(l)
  print(m)
  k=m[2]
  l.remove(m)

if f==0:
  print('No path found to destination')

# {'a':(0,0),'b':(2,2),'c':(3,1),'d':(4,3),'e':(4,8),'f':(5,2),'g':(6,0)}
# [['a','b'],['a','c'],['b','d'],['c','e'],['d','f'],['e','f'],['f','g']]

# %%
# min-max

# %%
# 8.	Implement Game trees using
# a.	MINIMAX algorithm

import math

def minimax (curDepth, nodeIndex, maxTurn):

	# base case : targetDepth reached
	if (curDepth == treeDepth):
		return scores[nodeIndex]

	if (maxTurn):
		return max(minimax(curDepth + 1, (nodeIndex) * 2 , False), minimax(curDepth + 1, nodeIndex * 2 +1 , False))

	else:
		return min(minimax(curDepth + 1, (nodeIndex )* 2 , True), minimax(curDepth + 1, nodeIndex * 2 +1, True))

# Driver code
scores = [3, 5, 2, 9, 12, 5, 23, 23]
# scores= list(map(int,input('Enter utility scores: ').split()))
# k=int(input('Enter initial turn, 1 for max or 0 for min: '))
k =1
treeDepth = math.log(len(scores), 2)

print("The optimal value is : ", end = "")

print(minimax(0, 0, k))

#3 5 2 9 12 5 23 23
# Out:
# The optimal value is : 12
